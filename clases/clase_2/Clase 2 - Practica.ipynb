# %% [markdown]
# # Analisis de los datos de EcoBici
#
# El objetico de esta práctica es que consulten el set de datos de Ecobici para el 2019. En las celdas irán encontrando elementos para pensar una búsqueda posible, pero es una práctica para ustedes, sin consignas estrictas ni respuestas correctas o equivocadas. Es preferible que dediquen sus horas en búsquedas que les resulten interesantes a uds. Si en lugar de prácticar con este dataset quieren practicar con otro, bienvenido sea. Pero pratiquen!

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#esta parte cambia en los Drive de cada uno
ruta_del_directorio = '/content/gdrive/My Drive/Analisis espacial/'

#si se hacen una copia de todo el directorio, esto deberia seguir igual
ruta_del_archivo = 'untref_analisis_espacial_2020/data/ecobici_2019_octubre.csv'

# %%
#importen las librerias necesarias
import

# %%
#les dejo la direccion del archivo original, pero pesa 1.5Gb
url_full_dataset_2019 = 'http://cdn.buenosaires.gob.ar/datosabiertos/datasets/transporte/bicicletas-publicas/recorridos-realizados-2019.csv'

#puden usar un archivo con solo los datos de octubre
ruta_datos_octubre = ruta_del_directorio + ruta_del_archivo

# %%
ruta_datos_octubre
# Out:
# '/content/gdrive/My Drive/Analisis espacial/untref_analisis_espacial_2020/data/ecobici_2019_octubre.csv'

# %%
path = '/content/gdrive/My Drive/Analisis espacial/untref_analisis_espacial_2020/data/ecobici_2019_octubre.csv'

# %%
 viajes  = pd.read_csv(path)
 viajes.sample(3)
# Out:
#         id_usuario  edad_usuario  ...  long_estacion_destino servicio
# 469826      506141           NaN  ...             -58.401924  antiguo
# 360243      409014           NaN  ...             -58.412738  antiguo
# 623864      373513           NaN  ...             -58.493419  antiguo
#
# [3 rows x 19 columns]

# %% [markdown]
# Trabajen con las columnas de fechas:
# - `fecha_origen_recorrido`
# - `fecha_destino_recorrido`
#
# 1. Extraigan de esas columnas la hora, el día, el tipo de día, el mes.
#
# 1. Observen como se comporta la cantidad de viajes por día, tipo de día o tipo de `servicio` (vieja concesión o TemBici)
#
# 1. Pueden elegir solamente un mes para trabajar con menos datos.
#
# 1. Qué estaciones son las más usadas?
#
# 1. Cambia con el tiempo?
#
#
#
# Pueden investigar el parámetro `parse_dates` en `pd.read_csv()`. Un consejo, al comienzo para poder investigar y probar el código, trabajen con una pequeña porción de los datos. Una vez que están seguros de que el código hace lo que uds desean, entonces procesen todos los datos.
#
# Para esto investiguen el parámetro `nrows` de en `pd.read_csv()`
